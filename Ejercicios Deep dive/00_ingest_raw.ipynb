# %% [markdown]
# d-sandbox
#
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 600px">
# </div>

# %% [markdown]
# # Retrieve Raw Data
#
# **Objective:** In this notebook, you will ingest data from a remote source into our source directory, `raw`.

# %% [markdown]
# ## Notebook Configuration
#
# Before you run this cell, make sure to add a unique user name to the file
# <a href="$./includes/configuration" target="_blank">
# includes/configuration</a>, e.g.
#
# `username = "yourfirstname_yourlastname"`

# %%
# %run ./includes/configuration
# Out:
# Out[3]: DataFrame[]

# %% [markdown]
# ## Make Course Idempotent

# %%
dbutils.fs.rm(health_tracker, recurse=True)

spark.sql(f"""
DROP TABLE IF EXISTS health_tracker_processed
""")

spark.sql(f"""
DROP TABLE IF EXISTS health_tracker_gold_aggregate_heartrate
""")
# Out:
# Out[5]: DataFrame[]

# %% [markdown]
# ## Retrieve First Month of Data
#
# Next, we use the utility function, `retrieve_data` to
# retrieve the files we will ingest. The function takes
# three arguments:
#
# - `year: int`
# - `month: int`
# - `rawPath: str`
# - `is_late: bool` (optional)

# %%
retrieve_data(2020, 1, health_tracker + "raw/")
retrieve_data(2020, 2, health_tracker + "raw/")
retrieve_data(2020, 2, health_tracker + "raw/", is_late=True)
retrieve_data(2020, 3, health_tracker + "raw/")
# Out:
# Out[6]: True

# %% [markdown]
# ### Expected File
#
# The expected file has the following name:

# %%
file_2020_1 = "health_tracker_data_2020_1.json"

# %% [markdown]
# ### Display the Files in the Raw Path

# %%
display(dbutils.fs.ls(health_tracker + "raw/"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/dbacademy/dbacademy/lakehouse-with-delta-lake-dd/health-tracker/raw/health_tracker_data_2020_1.json</td><td>health_tracker_data_2020_1.json</td><td>310628</td><td>1654511584000</td></tr><tr><td>dbfs:/dbacademy/dbacademy/lakehouse-with-delta-lake-dd/health-tracker/raw/health_tracker_data_2020_2.json</td><td>health_tracker_data_2020_2.json</td><td>284670</td><td>1654511584000</td></tr><tr><td>dbfs:/dbacademy/dbacademy/lakehouse-with-delta-lake-dd/health-tracker/raw/health_tracker_data_2020_3.json</td><td>health_tracker_data_2020_3.json</td><td>402785</td><td>1654511585000</td></tr><tr><td>dbfs:/dbacademy/dbacademy/lakehouse-with-delta-lake-dd/health-tracker/raw/late/</td><td>late/</td><td>0</td><td>0</td></tr></tbody></table></div>

# %% [markdown]
# **Exercise:** Write an Assertion Statement to Verify File Ingestion
#
# Note: the `print` statement would typically not be included in production code, nor in code used to test this notebook.

# %%
# ANSWER
assert file_2020_1 in [
    item.name for item in dbutils.fs.ls(health_tracker + "raw/")
], "File not present in Raw Path"
print("Assertion passed.")

# %% [markdown]
# -sandbox
# &copy; 2020 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="http://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="http://help.databricks.com/">Support</a>
